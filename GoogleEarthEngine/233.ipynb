# %%
import ee
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=PhvlVtF95ky5HgOEvaURPY71ILoFOL3YTNvOelb6aCQ&tc=WIBy-EM6f_jNRnoaTkA-0UqGmWiv_FXJZevV2JSv0o0&cc=m04_zrZbDGk0MIqMPnDQEWo63w0GqAO_atMrE6kD6Rw>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=PhvlVtF95ky5HgOEvaURPY71ILoFOL3YTNvOelb6aCQ&tc=WIBy-EM6f_jNRnoaTkA-0UqGmWiv_FXJZevV2JSv0o0&cc=m04_zrZbDGk0MIqMPnDQEWo63w0GqAO_atMrE6kD6Rw</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.
# ...

# %%
ee.Initialize()
print(ee.Image("NASA/NASADEM_HGT/001").get("title").getInfo())
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File f:\Users\TED223\anaconda3\envs\mytorch92\lib\site-packages\urllib3\connectionpool.py:700, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     699 if is_new_proxy_conn and http_tunnel_required:
# --> 700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
#
# File f:\Users\TED223\anaconda3\envs\mytorch92\lib\site-packages\urllib3\connectionpool.py:996, in HTTPSConnectionPool._prepare_proxy(self, conn)
#     994     conn.tls_in_tls_required = True
# --> 996 conn.connect()
#
# File f:\Users\TED223\anaconda3\envs\mytorch92\lib\site-packages\urllib3\connection.py:364, in HTTPSConnection.connect(self)
#     363 if self.tls_in_tls_required:
# ...
