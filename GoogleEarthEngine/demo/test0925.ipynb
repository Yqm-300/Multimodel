# %%
import ee
import geemap
import os
ee.Authenticate()
os.environ['HTTP_PROXY']='http://127.0.0.1:7890'
os.environ['HTTPS_PROXY']='http://127.0.0.1:7890'
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=FTSI5SM0GIqpbCHAMR0rVZw2m8_-wphnhm5au6GUPPU&tc=qxK5yt3PmW4tZ6zgwqgbAf_0zyk9sK1tFZATd1MrFMo&cc=zuwZjy0cYT1Kb5QkMeN3XVgpjwK4m8CsCqCMk4a7M50>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=FTSI5SM0GIqpbCHAMR0rVZw2m8_-wphnhm5au6GUPPU&tc=qxK5yt3PmW4tZ6zgwqgbAf_0zyk9sK1tFZATd1MrFMo&cc=zuwZjy0cYT1Kb5QkMeN3XVgpjwK4m8CsCqCMk4a7M50</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %%
# 加载中国的行政边界数据（已经上传到 GEE）
china_boundary = ee.FeatureCollection("projects/chancy479/assets/province")
guangxi_cities = ee.FeatureCollection("projects/chancy479/assets/city2")

GX = china_boundary.filterMetadata('ID','equals','Guangxi')
GX_cities=guangxi_cities.filterMetadata('省','equals','广西壮族自治区')

GX_bounds=GX_cities.geometry().bounds()
GX_geometry=GX_cities.geometry()

# %%
#导入并筛选
dataset=ee.ImageCollection("MODIS/061/MOD11A1")
filtered_dataset = dataset.filterBounds(GX).filterDate('2022-07-01', '2022-8-15')
print('图片数量：', dataset.size().getInfo())
# Out:
# 图片数量： 8533

# %%
print(filtered_dataset.getInfo())
# Out:
# {'type': 'ImageCollection', 'bands': [], 'version': 1694732802443753, 'id': 'MODIS/061/MOD11A1', 'properties': {'system:is_global': 1}, 'features': [{'type': 'Image', 'bands': [{'id': 'LST_Day_1km', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'QC_Day', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'Day_view_time', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'Day_view_angle', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'LST_Night_1km', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'QC_Night', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'Night_view_time', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'Night_view_angle', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'Emis_31', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'Emis_32', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'Clear_day_cov', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'Clear_night_cov', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}], 'version': 1658102923488563, 'id': 'MODIS/061/MOD11A1/2022_07_01', 'properties': {'system:time_start': 1656633600000, 'google:max_source_file_timestamp': 1657158762000, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-180, -90], [180, -90], [180, 90], [-180, 90], [-180, -90]]}, 'system:time_end': 1656720000000, 'system:asset_size': 802341909, 'system:index': '2022_07_01'}}, {'type': 'Image', 'bands': [{'id': 'LST_Day_1km', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [43200, 21600], 'crs': 'SR-ORG:6974', 'crs_transform': [926.6254331383326, 0, -20015109.355797, 0, -926.6254331391667, 10007554.677903]}, {'id': 'QC_Day', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [432 ...
